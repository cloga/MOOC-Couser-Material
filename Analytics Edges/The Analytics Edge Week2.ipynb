# %% [markdown]
# # Quick Question2

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.formula.api import ols
import patsy
from scipy.stats import describe

# %%
ob = [[0,2], [1, 2], [1, 8]]
def get_y(x):
    return 3 * x + 2
def get_SSE(y_r, y_pre):
    SSE = 0
    for i, v in enumerate(y_r):
        SSE += (y_r[i] - y_pre[i]) ** 2
    return SSE
y_r = [i[1] for i in ob]
x_l = [i[0] for i in ob]

# %%
y_pre = [get_y(x) for x in x_l]

# %%
SSE = get_SSE(y_r, y_pre)

# %%
y_r[1]
# Out:
# 2

# %%
y_pre[1]
# Out:
# 5

# %%
np.array(y_r).var()
# Out:
# 8.0

# %%
y_r = np.array(y_r)

# %%
y_r
# Out:
# array([2, 2, 8])

# %%
y_r.mean()
# Out:
# 4.0

# %%
y_r.std()
# Out:
# 2.8284271247461903

# %%
y_pre
# Out:
# [2, 5, 5]

# %%
y_r.var()
# Out:
# 8.0

# %%
SST = get_SSE(y_r, [4, 4, 4])

# %%
r2 = 1 -(SSE / float(SST))

# %%
r2
# Out:
# 0.25

# %%
np.array(y_r).mean()
# Out:
# 4.0

# %% [markdown]
# # Video 4

# %%
wine_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/wine.csv'
wine_test_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/wine_test.csv'

# %%
wine = pd.read_csv(wine_url)

# %%
wine.dtypes
# Out:
# Year             int64
# Price          float64
# WinterRain       int64
# AGST           float64
# HarvestRain      int64
# Age              int64
# FrancePop      float64
# dtype: object

# %%
wine.shape
# Out:
# (25, 7)

# %%
model1 = LinearRegression().fit(wine[['AGST']], wine['Price'])
print model1.score(wine[['AGST']], wine['Price'])
print model1.coef_
print model1.intercept_
# Out:
# 0.4350231678
# [ 0.63509431]
# -3.41776131349

# %%
y = wine['Price']
X = wine[['AGST']]
X = sm.add_constant(X)
model1 = sm.OLS(y, X)
res = model1.fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.435
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     17.71
# Date:                Sat, 15 Mar 2014   Prob (F-statistic):           0.000335
# Time:                        20:42:26   Log-Likelihood:                -17.070
# No. Observations:                  25   AIC:                             38.14
# Df Residuals:                      23   BIC:                             40.58
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         -3.4178      2.494     -1.371      0.184        -8.576     1.740
# AGST           0.6351      0.151      4.208      0.000         0.323     0.947
# ...

# %%
y = wine['Price']
X = wine[['HarvestRain', 'WinterRain']]
X = sm.add_constant(X)
model2 = sm.OLS(y, X)
res = model2.fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.256
# Method:                 Least Squares   F-statistic:                     5.122
# Date:                Sat, 15 Mar 2014   Prob (F-statistic):             0.0149
# Time:                        20:42:29   Log-Likelihood:                -19.428
# No. Observations:                  25   AIC:                             44.86
# Df Residuals:                      22   BIC:                             48.51
# Df Model:                           2
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const           7.8653      0.662     11.888      0.000         6.493     9.237
# HarvestRain    -0.0050      0.002     -3.105      0.005        -0.008    -0.002
# ...

# %%
y = wine['Price']
columns = [c for c in wine if c not in ['Price']]
X = wine[columns]
X = sm.add_constant(X)
model = sm.OLS(y, X)
res = model.fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.784
# Method:                 Least Squares   F-statistic:                     18.47
# Date:                Sat, 15 Mar 2014   Prob (F-statistic):           1.04e-06
# Time:                        20:58:03   Log-Likelihood:                -2.1043
# No. Observations:                  25   AIC:                             16.21
# Df Residuals:                      19   BIC:                             23.52
# Df Model:                           5
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const         6.58e-08   3.48e-05      0.002      0.999     -7.28e-05  7.29e-05
# Year           -0.0002      0.005     -0.044      0.965        -0.011     0.011
# ...

# %%
wine.corr()
# Out:
#                  Year     Price  WinterRain      AGST  HarvestRain       Age  \
# Year         1.000000 -0.447768    0.016970 -0.246916     0.028009 -1.000000
# Price       -0.447768  1.000000    0.136651  0.659563    -0.563322  0.447768
# WinterRain   0.016970  0.136651    1.000000 -0.321091    -0.275441 -0.016970
# AGST        -0.246916  0.659563   -0.321091  1.000000    -0.064496  0.246916
# HarvestRain  0.028009 -0.563322   -0.275441 -0.064496     1.000000 -0.028009
# Age         -1.000000  0.447768   -0.016970  0.246916    -0.028009  1.000000
# FrancePop    0.994485 -0.466862   -0.001622 -0.259162     0.041264 -0.994485
#
#              FrancePop
# Year          0.994485
# Price        -0.466862
# WinterRain   -0.001622
# AGST         -0.259162
# HarvestRain   0.041264
# Age          -0.994485
# FrancePop     1.000000
#
# [7 rows x 7 columns]

# %%
y = wine['Price']
columns = ['HarvestRain', 'WinterRain']
X = wine[columns]
X = sm.add_constant(X)
model = sm.OLS(y, X)
res = model.fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.256
# Method:                 Least Squares   F-statistic:                     5.122
# Date:                Sat, 15 Mar 2014   Prob (F-statistic):             0.0149
# Time:                        21:11:41   Log-Likelihood:                -19.428
# No. Observations:                  25   AIC:                             44.86
# Df Residuals:                      22   BIC:                             48.51
# Df Model:                           2
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const           7.8653      0.662     11.888      0.000         6.493     9.237
# HarvestRain    -0.0050      0.002     -3.105      0.005        -0.008    -0.002
# ...

# %% [markdown]
# # money ball

# %%
money_ball_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/baseball.csv'
baseball = pd.read_csv(money_ball_url)

# %%
moneyball = baseball.query('Year < 2002')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/computation/ops.py:62: DeprecationWarning: object() takes no parameters
#   return supr_new(klass, name, env, side=side, encoding=encoding)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/computation/ops.py:62: DeprecationWarning: object() takes no parameters
#   return supr_new(klass, name, env, side=side, encoding=encoding)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numexpr/necompiler.py:742: DeprecationWarning: using `oa_ndim == 0` when `op_axes` is NULL is deprecated. Use `oa_ndim == -1` or the MultiNew iterator for NumPy <1.8 compatibility
#   return compiled_ex(*arguments, **kwargs)

# %%
moneyball
# Out:
#     Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 330  ANA     AL  2001  691  730   75  0.327  0.405  0.261         0
# 331  ARI     NL  2001  818  677   92  0.341  0.442  0.267         1
# 332  ATL     NL  2001  729  643   88  0.324  0.412  0.260         1
# 333  BAL     AL  2001  687  829   63  0.319  0.380  0.248         0
# 334  BOS     AL  2001  772  745   82  0.334  0.439  0.266         0
# 335  CHC     NL  2001  777  701   88  0.336  0.430  0.261         0
# 336  CHW     AL  2001  798  795   83  0.334  0.451  0.268         0
# 337  CIN     NL  2001  735  850   66  0.324  0.419  0.262         0
# 338  CLE     AL  2001  897  821   91  0.350  0.458  0.278         1
# 339  COL     NL  2001  923  906   73  0.354  0.483  0.292         0
# 340  DET     AL  2001  724  876   66  0.320  0.409  0.260         0
# 341  FLA     NL  2001  742  744   76  0.326  0.423  0.264         0
# 342  HOU     NL  2001  847  769   93  0.347  0.451  0.271         1
# ...

# %%
moneyball['RD'] = moneyball['RS'] - moneyball['RA']

# %%
y = moneyball['W']
columns = ['RD']
X = moneyball[columns]
X = sm.add_constant(X)
WinReg = sm.OLS(y, X)
res = WinReg.fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      W   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     6651.
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):               0.00
# Time:                        09:52:38   Log-Likelihood:                -2515.5
# No. Observations:                 902   AIC:                             5035.
# Df Residuals:                     900   BIC:                             5045.
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         80.8814      0.131    616.675      0.000        80.624    81.139
# RD             0.1058      0.001     81.554      0.000         0.103     0.108
# ...

# %%
RS = 713
RA = 614
RD = RS - RA

# %%
RD
# Out:
# 99

# %%
W = 80.8814 + 0.1058 * RD

# %%
W
# Out:
# 91.3556

# %%
y = moneyball['RS']
columns = ['OBP', 'SLG']
X = moneyball[columns]
X = sm.add_constant(X)
RunsReg = sm.OLS(y, X).fit()
print RunsReg.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     RS   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     5934.
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):               0.00
# Time:                        10:30:36   Log-Likelihood:                -4174.2
# No. Observations:                 902   AIC:                             8354.
# Df Residuals:                     899   BIC:                             8369.
# Df Model:                           2
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       -804.6271     18.921    -42.526      0.000      -841.761  -767.493
# OBP         2737.7680     90.685     30.190      0.000      2559.790  2915.746
# ...

# %%
model = LinearRegression().fit(moneyball[['OBP', 'SLG']], y)
model.predict([0.311, 0.405])
# Out:
# 688.70677907560071

# %%
res.predict([1, 0.311, 0.405])
# Out:
# 688.7067790756048

# %%
moneyball1 = moneyball.ix[moneyball['OOBP'].notnull()]
y = moneyball1['RA']
columns = ['OOBP', 'OSLG']
X = moneyball1[columns]
X = sm.add_constant(X)
RunsAll = sm.OLS(y, X).fit()
print RunsAll.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     RA   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     425.8
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):           1.16e-45
# Time:                        10:59:03   Log-Likelihood:                -418.27
# No. Observations:                  90   AIC:                             842.5
# Df Residuals:                      87   BIC:                             850.0
# Df Model:                           2
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       -837.3779     60.255    -13.897      0.000      -957.142  -717.614
# OOBP        2913.5995    291.971      9.979      0.000      2333.276  3493.923
# ...

# %%
RunsAll.predict([1, 0.297, 0.370])
# Out:
# 588.24696328791595

# %%
moneyball
# Out:
#     Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 330  ANA     AL  2001  691  730   75  0.327  0.405  0.261         0
# 331  ARI     NL  2001  818  677   92  0.341  0.442  0.267         1
# 332  ATL     NL  2001  729  643   88  0.324  0.412  0.260         1
# 333  BAL     AL  2001  687  829   63  0.319  0.380  0.248         0
# 334  BOS     AL  2001  772  745   82  0.334  0.439  0.266         0
# 335  CHC     NL  2001  777  701   88  0.336  0.430  0.261         0
# 336  CHW     AL  2001  798  795   83  0.334  0.451  0.268         0
# 337  CIN     NL  2001  735  850   66  0.324  0.419  0.262         0
# 338  CLE     AL  2001  897  821   91  0.350  0.458  0.278         1
# 339  COL     NL  2001  923  906   73  0.354  0.483  0.292         0
# 340  DET     AL  2001  724  876   66  0.320  0.409  0.260         0
# 341  FLA     NL  2001  742  744   76  0.326  0.423  0.264         0
# 342  HOU     NL  2001  847  769   93  0.347  0.451  0.271         1
# ...

# %%
print 'Eric Chavez', RunsReg.predict([1, 0.338, 0.540])
print 'Jeremy Giambi', RunsReg.predict([1, 0.391, 0.450])
print 'Frank Menechino', RunsReg.predict([1, 0.369, 0.374])
print 'Greg Myers', RunsReg.predict([1, 0.313, 0.447])
print 'Carlos Pena', RunsReg.predict([1, 0.361, 0.500])
# Out:
# Eric Chavez 976.589177414
# Jeremy Giambi 979.049108103
# Frank Menechino 798.365157598
# Greg Myers 760.748476549
# Carlos Pena 976.161497708

# %%
teamRank = pd.Series([1,2,3,3,4,4,4,4,5,5])

# %%
wins2012 = pd.Series([94, 88, 95, 88, 93, 94, 98, 97, 93, 94])
wins2013 = pd.Series([97, 97, 92, 93, 92, 96, 94, 96, 92, 90])

# %%
teamRank.corr(wins2012)
# Out:
# 0.34771292491275146

# %%
teamRank.corr(wins2013)
# Out:
# -0.65569452153518726

# %%
np.corrcoef(teamRank, wins2012)
# Out:
# array([[ 1.        ,  0.34771292],
#        [ 0.34771292,  1.        ]])

# %%
np.correlate(teamRank, wins2012)
# Out:
# array([3282])

# %% [markdown]
# #NBA

# %%
nba_train_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/NBA_train.csv'
nba_test_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/NBA_test.csv'

# %%
NBA = pd.read_csv(nba_train_url)

# %%
NBA.dtypes
# Out:
# SeasonEnd     int64
# Team         object
# Playoffs      int64
# W             int64
# PTS           int64
# oppPTS        int64
# FG            int64
# FGA           int64
# 2P            int64
# 2PA           int64
# 3P            int64
# 3PA           int64
# FT            int64
# FTA           int64
# ORB           int64
# DRB           int64
# AST           int64
# STL           int64
# BLK           int64
# TOV           int64
# dtype: object

# %% [markdown]
# # HomeWork
# ## STATE DATA

# %%
from rpy2.robjects import r
from rpy2 import robjects
r.data('state')
import pandas.rpy.common as com
# kobe = com.load_data('kobe')
import pandas as pd

# %%
# %load_ext rmagic
# %R data(state)
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic
# array(['state'],
#       dtype='|S5')

# %%
statedata = com.load_data('state.x77')
statedata['abb'] = com.load_data('state.abb')
statedata['area']= com.load_data('state.area')
state_center = com.load_data('state.center')
statedata['division'] = com.load_data('state.division')
statedata['name'] = com.load_data('state.name')
statedata['region'] = com.load_data('state.region')
statedata['x'] = state_center['x']
statedata['y'] = state_center['y']

# %%
statedata
# Out:
#                 Population  Income  Illiteracy  Life Exp  Murder  HS Grad  \
# Alabama               3615    3624         2.1     69.05    15.1     41.3
# Alaska                 365    6315         1.5     69.31    11.3     66.7
# Arizona               2212    4530         1.8     70.55     7.8     58.1
# Arkansas              2110    3378         1.9     70.66    10.1     39.9
# California           21198    5114         1.1     71.71    10.3     62.6
# Colorado              2541    4884         0.7     72.06     6.8     63.9
# Connecticut           3100    5348         1.1     72.48     3.1     56.0
# Delaware               579    4809         0.9     70.06     6.2     54.6
# Florida               8277    4815         1.3     70.66    10.7     52.6
# Georgia               4931    4091         2.0     68.54    13.9     40.6
# Hawaii                 868    4963         1.9     73.60     6.2     61.9
# Idaho                  813    4119         0.6     71.87     5.3     59.5
# ...

# %%
statedata.plot(x='x', y='y', kind='scatter')

# %%
statedata.groupby('region')['HS Grad'].mean()
# Out:
# region
# North Central    54.516667
# Northeast        53.966667
# South            44.343750
# West             62.000000
# Name: HS Grad, dtype: float64

# %%
statedata[['Murder', 'region']].boxplot(by='region')

# %%
statedata[['Murder', 'region']].ix[statedata['region'] == 'Northeast']
# Out:
#                Murder     region
# Connecticut       3.1  Northeast
# Maine             2.7  Northeast
# Massachusetts     3.3  Northeast
# New Hampshire     3.3  Northeast
# New Jersey        5.2  Northeast
# New York         10.9  Northeast
# Pennsylvania      6.1  Northeast
# Rhode Island      2.4  Northeast
# Vermont           5.5  Northeast
#
# [9 rows x 2 columns]

# %%
y = statedata['Life Exp']
columns = [u'Population', u'Income', u'Illiteracy',  u'Murder', u'HS Grad', u'Frost', u'Area']
X = statedata[columns]
X = sm.add_constant(X)
lifeReg = sm.OLS(y, X).fit()
print lifeReg.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Life Exp   R-squared:                       0.736
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     16.74
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):           2.53e-10
# Time:                        15:17:35   Log-Likelihood:                -51.855
# No. Observations:                  50   AIC:                             119.7
# Df Residuals:                      42   BIC:                             135.0
# Df Model:                           7
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         70.9432      1.748     40.586      0.000        67.416    74.471
# Population   5.18e-05   2.92e-05      1.775      0.083      -7.1e-06     0.000
# ...

# %%
statedata.columns
# Out:
# Index([u'Population', u'Income', u'Illiteracy', u'Life Exp', u'Murder', u'HS Grad', u'Frost', u'Area', u'abb', u'area', u'division', u'name', u'region', u'x', u'y'], dtype='object')

# %%
statedata.plot(x='Income', y='Life Exp', kind='scatter')

# %%
X.corr()
# Out:
#             const  Population    Income  Illiteracy    Murder   HS Grad  \
# const         NaN         NaN       NaN         NaN       NaN       NaN
# Population    NaN    1.000000  0.208228    0.107622  0.343643 -0.098490
# Income        NaN    0.208228  1.000000   -0.437075 -0.230078  0.619932
# Illiteracy    NaN    0.107622 -0.437075    1.000000  0.702975 -0.657189
# Murder        NaN    0.343643 -0.230078    0.702975  1.000000 -0.487971
# HS Grad       NaN   -0.098490  0.619932   -0.657189 -0.487971  1.000000
# Frost         NaN   -0.332152  0.226282   -0.671947 -0.538883  0.366780
# Area          NaN    0.022544  0.363315    0.077261  0.228390  0.333542
#
#                Frost      Area
# const            NaN       NaN
# Population -0.332152  0.022544
# Income      0.226282  0.363315
# Illiteracy -0.671947  0.077261
# Murder     -0.538883  0.228390
# HS Grad     0.366780  0.333542
# Frost       1.000000  0.059229
# Area        0.059229  1.000000
#
# [8 rows x 8 columns]

# %%
y = statedata['Life Exp']
columns = [u'Population',  u'Murder', u'HS Grad', u'Frost']
X = statedata[columns]
X = sm.add_constant(X)
lifeReg = sm.OLS(y, X).fit()
print lifeReg.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Life Exp   R-squared:                       0.736
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     31.37
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):           1.70e-12
# Time:                        15:28:53   Log-Likelihood:                -51.866
# No. Observations:                  50   AIC:                             113.7
# Df Residuals:                      45   BIC:                             123.3
# Df Model:                           4
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         71.0271      0.953     74.542      0.000        69.108    72.946
# Population  5.014e-05   2.51e-05      1.996      0.052     -4.54e-07     0.000
# ...

# %%
statedata['life_Exp_p'] = lifeReg.predict(X)

# %%
statedata['life_Exp_p'].order()
# Out:
# Alabama           68.481119
# Georgia           68.636942
# Mississippi       69.005354
# South Carolina    69.061092
# Louisiana         69.150448
# Kentucky          69.244179
# North Carolina    69.286242
# Tennessee         69.465833
# Nevada            69.524824
# Arkansas          69.573739
# Alaska            69.857404
# Michigan          69.868934
# Texas             69.978859
# New Mexico        70.031191
# Missouri          70.106100
# Virginia          70.146914
# Illinois          70.192442
# West Virginia     70.449826
# Maryland          70.518520
# Florida           70.615395
# New York          70.629371
# Wyoming           70.876789
# Indiana           70.901585
# Vermont           71.061350
# Ohio              71.085488
# Colorado          71.103542
# Delaware          71.126469
# Oklahoma          71.158600
# Pennsylvania      71.380455
# Montana           71.400248
# Arizona           71.414157
# Idaho             71.499893
# New Jersey        71.596121
# ...

# %%
statedata['Life Exp'].order()
# Out:
# South Carolina    67.96
# Mississippi       68.09
# Georgia           68.54
# Louisiana         68.76
# Nevada            69.03
# Alabama           69.05
# North Carolina    69.21
# Alaska            69.31
# West Virginia     69.48
# Delaware          70.06
# Virginia          70.08
# Kentucky          70.10
# Tennessee         70.11
# Illinois          70.14
# Maryland          70.22
# Wyoming           70.29
# New Mexico        70.32
# Maine             70.39
# Pennsylvania      70.43
# Arizona           70.55
# New York          70.55
# Montana           70.56
# Michigan          70.63
# Arkansas          70.66
# Florida           70.66
# Missouri          70.69
# Ohio              70.82
# Indiana           70.88
# Texas             70.90
# New Jersey        70.93
# New Hampshire     71.23
# Oklahoma          71.42
# Vermont           71.64
# California        71.71
# Washington        71.72
# Massachusetts     71.83
# Idaho             71.87
# Rhode Island      71.90
# ...

# %%
(statedata['Life Exp'] - statedata['life_Exp_p']).abs().order()
# Out:
# Indiana           0.021585
# Florida           0.044605
# Illinois          0.052442
# Virginia          0.066914
# South Dakota      0.068391
# North Carolina    0.076242
# New York          0.079371
# California        0.085646
# Georgia           0.096942
# Rhode Island      0.139930
# Iowa              0.163471
# Oklahoma          0.261400
# Ohio              0.265488
# Oregon            0.284453
# New Mexico        0.288809
# Maryland          0.298520
# Idaho             0.370107
# Louisiana         0.390448
# Nebraska          0.429677
# Connecticut       0.445410
# Wisconsin         0.470043
# Nevada            0.494824
# New Hampshire     0.496356
# Alaska            0.547404
# Alabama           0.568881
# Vermont           0.578650
# Missouri          0.583900
# Wyoming           0.586789
# Massachusetts     0.611054
# Tennessee         0.644167
# New Jersey        0.666121
# Kansas            0.676480
# Minnesota         0.694404
# Michigan          0.761066
# ...

# %% [markdown]
# ##CLIMATE CHANGE

# %%
url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/climate_change.csv'
climate_change = pd.read_csv(url)
climate_change.columns
# Out:
# Index([u'Year', u'Month', u'MEI', u'CO2', u'CH4', u'N2O', u'CFC-11', u'CFC-12', u'TSI', u'Aerosols', u'Temp'], dtype='object')

# %%
train = climate_change.ix[climate_change[u'Year'] <= 2006]
test = climate_change.ix[climate_change[u'Year'] > 2006]

# %%
y = train[u'Temp']
columns = [u'MEI', u'CO2', u'CH4', u'N2O', u'CFC-11', u'CFC-12', u'TSI', u'Aerosols']
X = train[columns]
X = sm.add_constant(X)
TemReg = sm.OLS(y, X).fit()
print TemReg.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   Temp   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     103.6
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):           1.94e-78
# Time:                        16:00:53   Log-Likelihood:                 280.10
# No. Observations:                 284   AIC:                            -542.2
# Df Residuals:                     275   BIC:                            -509.4
# Df Model:                           8
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       -124.5943     19.887     -6.265      0.000      -163.744   -85.445
# MEI            0.0642      0.006      9.923      0.000         0.051     0.077
# ...

# %%
train.corr()
# Out:
#               Year     Month       MEI       CO2       CH4       N2O  \
# Year      1.000000 -0.027942 -0.036988  0.982749  0.915659  0.993845
# Month    -0.027942  1.000000  0.000885 -0.106732  0.018569  0.013632
# MEI      -0.036988  0.000885  1.000000 -0.041147 -0.033419 -0.050820
# CO2       0.982749 -0.106732 -0.041147  1.000000  0.877280  0.976720
# CH4       0.915659  0.018569 -0.033419  0.877280  1.000000  0.899839
# N2O       0.993845  0.013632 -0.050820  0.976720  0.899839  1.000000
# CFC-11    0.569106 -0.013111  0.069000  0.514060  0.779904  0.522477
# CFC-12    0.897012  0.000675  0.008286  0.852690  0.963616  0.867931
# TSI       0.170302 -0.034606 -0.154492  0.177429  0.245528  0.199757
# Aerosols -0.345247  0.014890  0.340238 -0.356155 -0.267809 -0.337055
# Temp      0.786797 -0.099857  0.172471  0.788529  0.703255  0.778639
#
#             CFC-11    CFC-12       TSI  Aerosols      Temp
# Year      0.569106  0.897012  0.170302 -0.345247  0.786797
# ...

# %%
y = train[u'Temp']
columns = [u'MEI', u'N2O', u'TSI', u'Aerosols']
X = train[columns]
X = sm.add_constant(X)
TemReg = sm.OLS(y, X).fit()
print TemReg.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   Temp   R-squared:                       0.726
# Model:                            OLS   Adj. R-squared:                  0.722
# Method:                 Least Squares   F-statistic:                     184.9
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):           3.52e-77
# Time:                        16:10:55   Log-Likelihood:                 266.64
# No. Observations:                 284   AIC:                            -523.3
# Df Residuals:                     279   BIC:                            -505.0
# Df Model:                           4
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       -116.2269     20.223     -5.747      0.000      -156.036   -76.418
# MEI            0.0642      0.007      9.649      0.000         0.051     0.077
# ...

# %%
from sklearn import linear_model
clf = linear_model.LassoLarsIC(criterion='bic')
y = train[u'Temp']
columns = [u'MEI', u'CO2', u'CH4', u'N2O', u'CFC-11', u'CFC-12', u'TSI', u'Aerosols']
X = train[columns]
model = clf.fit(X, y)
print model.score(X, y)
print model.coef_
print model.intercept_
print model.alpha_
# Out:
# 0.747052395372
# [ 0.06296743  0.00513708  0.          0.         -0.00359629  0.00202874
#   0.08623147 -1.54564173]
# -119.49850639
# 2.76658461607e-05

# %%
y = train[u'Temp']
columns = [u'MEI', u'CO2', u'N2O', u'CFC-11', u'CFC-12', u'TSI', u'Aerosols']
X = train[columns]
X = sm.add_constant(X)
TemReg = sm.OLS(y, X).fit()
print TemReg.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   Temp   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     118.8
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):           1.77e-79
# Time:                        16:50:00   Log-Likelihood:                 280.07
# No. Observations:                 284   AIC:                            -544.1
# Df Residuals:                     276   BIC:                            -515.0
# Df Model:                           7
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       -124.5152     19.850     -6.273      0.000      -163.592   -85.438
# MEI            0.0641      0.006      9.958      0.000         0.051     0.077
# ...

# %%
test.columns
# Out:
# Index([u'Year', u'Month', u'MEI', u'CO2', u'CH4', u'N2O', u'CFC-11', u'CFC-12', u'TSI', u'Aerosols', u'Temp'], dtype='object')

# %%
test_x = sm.add_constant(test[columns])
y_p = TemReg.predict(test_x)
SSE = ((TemReg.predict(test_x) - test['Temp']) **2).sum()
SST = ((test['Temp'] - train['Temp'].mean()) **2).sum()
1 - SSE / SST
# Out:
# 0.6286051225100745

# %%
clf = LinearRegression()
y = train[u'Temp']
columns = [u'MEI', u'CO2', u'N2O', u'CFC-11', u'CFC-12', u'TSI', u'Aerosols']
X = train[columns]
model = clf.fit(X, y)
print y_p
y_p = model.predict(test[columns])
print y_p
print model.score(X, y)
print model.coef_
print model.intercept_
print model.score(test[columns], test['Temp'])
# Out:
# [ 0.46778077  0.44354042  0.42655406  0.42991621  0.44551127  0.41514218
#   0.40973665  0.38393904  0.32555954  0.32741473  0.32314008  0.3316704
#   0.35221342  0.33131285  0.31421118  0.37034101  0.41622127  0.43914579
#   0.42379653  0.39136791  0.35876147  0.34519907  0.36070869  0.36380763]
# [ 0.46778077  0.44354042  0.42655406  0.42991621  0.44551127  0.41514218
#   0.40973665  0.38393904  0.32555954  0.32741473  0.32314008  0.3316704
#   0.35221342  0.33131285  0.31421118  0.37034101  0.41622127  0.43914579
#   0.42379653  0.39136791  0.35876147  0.34519907  0.36070869  0.36380763]
# 0.750840896222
# [ 0.06406779  0.0064015  -0.01602113 -0.00660935  0.00386756  0.09311551
#  -1.54020582]
# -124.515177827
# 0.186406487518

# %% [markdown]
# ##READING TEST SCORES

# %%
pisa_train_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/pisa2009train.csv'
pisa_test_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/pisa2009test.csv'
pisa_train = pd.read_csv(pisa_train_url)
pisa_test = pd.read_csv(pisa_test_url)

# %%
pisa_train.shape
# Out:
# (3663, 24)

# %%
for i in pisa_train:
    print i
    print pisa_train[i].isnull().value_counts()
# Out:
# grade
# False    3663
# dtype: int64
# male
# False    3663
# dtype: int64
# raceeth
# False    3628
# True       35
# dtype: int64
# preschool
# False    3607
# True       56
# dtype: int64
# expectBachelors
# False    3601
# True       62
# dtype: int64
# motherHS
# False    3566
# True       97
# dtype: int64
# motherBachelors
# False    3266
# True      397
# dtype: int64
# motherWork
# False    3570
# True       93
# dtype: int64
# fatherHS
# False    3418
# True      245
# dtype: int64
# fatherBachelors
# False    3094
# True      569
# dtype: int64
# fatherWork
# False    3430
# True      233
# dtype: int64
# selfBornUS
# False    3594
# True       69
# dtype: int64
# motherBornUS
# False    3592
# True       71
# dtype: int64
# fatherBornUS
# False    3550
# True      113
# dtype: int64
# englishAtHome
# False    3592
# True       71
# dtype: int64
# computerForSchoolwork
# False    3598
# True       65
# dtype: int64
# read30MinsADay
# False    3629
# True       34
# ...

# %%
pisa_train = pisa_train.dropna()
pisa_test = pisa_test.dropna()

# %%
pisa_train.shape
# Out:
# (2414, 24)

# %%
pisa_test.shape
# Out:
# (990, 24)

# %%
reduce(lambda x,y : x + ' + ' + y, pisa_train.columns)
# Out:
# 'grade + male + raceeth + preschool + expectBachelors + motherHS + motherBachelors + motherWork + fatherHS + fatherBachelors + fatherWork + selfBornUS + motherBornUS + fatherBornUS + englishAtHome + computerForSchoolwork + read30MinsADay + minutesPerWeekEnglish + studentsInEnglish + schoolHasLibrary + publicSchool + urban + schoolSize + readingScore'

# %%
formula = 'readingScore ~ grade + male + raceeth + preschool + expectBachelors + motherHS + motherBachelors + motherWork + fatherHS + fatherBachelors + fatherWork + selfBornUS + motherBornUS + fatherBornUS + englishAtHome + computerForSchoolwork + read30MinsADay + minutesPerWeekEnglish + studentsInEnglish + schoolHasLibrary + publicSchool + urban + schoolSize'
y,X = patsy.dmatrices(formula, pisa_train, return_type='dataframe')
lmScore = sm.OLS(y, X).fit()
lmScore.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           readingScore   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.317
# Method:                 Least Squares   F-statistic:                     41.04
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):          1.72e-180
# Time:                        22:27:59   Log-Likelihood:                -13795.
# No. Observations:                2414   AIC:                         2.765e+04
# Df Residuals:                    2385   BIC:                         2.781e+04
# Df Model:                          28
# ...
#                                                         coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rms = sqrt(mean_squared_error(pisa_train['readingScore'], lmScore.predict(X)))
print rms
# Out:
# 73.365551433

# %%
formula = 'readingScore ~ grade + male + raceeth + preschool + expectBachelors + motherHS + motherBachelors + motherWork + fatherHS + fatherBachelors + fatherWork + selfBornUS + motherBornUS + fatherBornUS + englishAtHome + computerForSchoolwork + read30MinsADay + minutesPerWeekEnglish + studentsInEnglish + schoolHasLibrary + publicSchool + urban + schoolSize'
testy,testX = patsy.dmatrices(formula, pisa_test, return_type='dataframe')
y_pre = pd.Series(lmScore.predict(testX))

# %%
y_pre.describe()
# Out:
# count    990.000000
# mean     516.710339
# std       52.034082
# min      353.223123
# 25%      482.030498
# 50%      523.980207
# 75%      555.701125
# max      637.691435
# dtype: float64

# %%
y_pre.max() - y_pre.min()
# Out:
# 284.46831179513816

# %%
SSE = ((y_pre.values - pisa_test['readingScore'].values) ** 2).sum()
SSE
# Out:
# 5762082.3711443525

# %%
rms = sqrt(mean_squared_error(pisa_test['readingScore'], y_pre))

# %%
rms ** 2 * 990
# Out:
# 5762082.371144352

# %%
pisa_test['readingScore']
# Out:
# 0     355.24
# 4     453.50
# 6     405.13
# 7     665.05
# 8     604.84
# 9     626.08
# 10    525.32
# 12    354.63
# 13    547.35
# 14    571.39
# 17    513.84
# 19    380.34
# 20    467.10
# 24    482.50
# 25    545.73
# ...
# 1550    593.05
# 1551    371.44
# 1552    617.79
# 1553    426.73
# 1554    638.12
# 1556    414.74
# 1558    562.18
# 1559    526.67
# 1560    582.55
# 1561    611.91
# 1562    667.20
# 1563    541.76
# 1565    465.58
# 1568    596.34
# 1569    577.43
# Name: readingScore, Length: 990, dtype: float64

# %%
y_pre
# Out:
# 0     471.986713
# 1     540.197379
# 2     429.752343
# 3     499.013868
# 4     564.021222
# 5     517.906435
# 6     530.593092
# 7     408.554557
# 8     538.939751
# 9     536.274399
# 10    477.833988
# 11    403.231911
# 12    460.333831
# 13    496.925540
# 14    519.095279
# ...
# 975    507.715773
# 976    500.602810
# 977    540.970610
# 978    529.969305
# 979    467.727745
# 980    488.679684
# 981    542.554560
# 982    600.492337
# 983    584.980115
# 984    560.322850
# 985    566.062998
# 986    548.723228
# 987    477.180293
# 988    591.620882
# 989    544.110890
# Length: 990, dtype: float64

# %%
pisa_train['readingScore'].mean()
# Out:
# 517.96288732394294

# %%
SST = ((pisa_test['readingScore'] - pisa_train['readingScore'].mean()) ** 2).sum()
SST
# Out:
# 7802354.0776138389

# %%
1 - SSE / SST
# Out:
# 0.26149437543770815

# %% [markdown]
# ## DETECTING FLU EPIDEMICS VIA SEARCH ENGINE QUERY DATA

# %%
flu_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/FluTrain.csv'
FluTrain = pd.read_csv(flu_url)

# %%
FluTrain.dtypes
# Out:
# Week        object
# ILI        float64
# Queries    float64
# dtype: object

# %%
FluTrain = FluTrain.set_index('Week')

# %%
FluTrain['ILI'].plot(figsize=(20,6))

# %%
FluTrain['ILI'].idxmax()
# Out:
# '2009-10-18 - 2009-10-24'

# %%
FluTrain['Queries'].idxmax()
# Out:
# '2009-10-18 - 2009-10-24'

# %%
FluTrain['ILI'].hist()

# %%
matplotlib.pyplot.scatter(np.log(FluTrain['ILI']),FluTrain['Queries'])

# %%
matplotlib.pyplot.scatter(FluTrain['ILI'],FluTrain['Queries'])

# %%
FluTrend1 = ols('np.log(ILI) ~ Queries', data = FluTrain)

# %%
FluTrend1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.log(ILI)   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0.708
# Method:                 Least Squares   F-statistic:                     1011.
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):          2.62e-113
# Time:                        23:38:03   Log-Likelihood:                -87.974
# No. Observations:                 417   AIC:                             179.9
# Df Residuals:                     415   BIC:                             188.0
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.4993      0.030    -16.422      0.000        -0.559    -0.440
# ...

# %%
FluTrend1 = sm.OLS(np.log(FluTrain['ILI']),(sm.add_constant(FluTrain['Queries']))).fit()

# %%
FluTrend1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    ILI   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0.708
# Method:                 Least Squares   F-statistic:                     1011.
# Date:                Sun, 16 Mar 2014   Prob (F-statistic):          2.62e-113
# Time:                        23:38:18   Log-Likelihood:                -87.974
# No. Observations:                 417   AIC:                             179.9
# Df Residuals:                     415   BIC:                             188.0
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         -0.4993      0.030    -16.422      0.000        -0.559    -0.440
# ...

# %%
FluTrain.corr()
# Out:
#               ILI   Queries
# ILI      1.000000  0.814212
# Queries  0.814212  1.000000
#
# [2 rows x 2 columns]

# %%
0.814212 ** 2
# Out:
# 0.6629411809440001

# %%
flu_test_url = 'https://courses.edx.org/c4x/MITx/15.071x/asset/FluTest.csv'
flutest = pd.read_csv(flu_test_url)

# %%
np.exp(FluTrend1.predict(sm.add_constant(flutest['Queries'])))[10]
# Out:
# 2.1873777211145442

# %%
(flutest.ix[10]['ILI'] - np.exp(FluTrend1.predict(sm.add_constant(flutest['Queries'])))[10]) / flutest.ix[10]['ILI']
# Out:
# 0.046238266364746414

# %%
RMSE = sqrt(((np.exp(FluTrend1.predict(sm.add_constant(flutest['Queries']))) - flutest['ILI'].values) ** 2).sum() / len(flutest))

# %%
RMSE
# Out:
# 0.7490645271019656

# %%
FluTrain['ILILag2'] = FluTrain['ILI'].shift(2)

# %%
FluTrain
# Out:
#                               ILI   Queries   ILILag2
# Week
# 2004-01-04 - 2004-01-10  2.418331  0.237716       NaN
# 2004-01-11 - 2004-01-17  1.809056  0.220452       NaN
# 2004-01-18 - 2004-01-24  1.712024  0.225764  2.418331
# 2004-01-25 - 2004-01-31  1.542495  0.237716  1.809056
# 2004-02-01 - 2004-02-07  1.437868  0.224436  1.712024
# 2004-02-08 - 2004-02-14  1.324274  0.207171  1.542495
# 2004-02-15 - 2004-02-21  1.307257  0.241700  1.437868
# 2004-02-22 - 2004-02-28  1.036977  0.216467  1.324274
# 2004-02-29 - 2004-03-06  1.010320  0.225764  1.307257
# 2004-03-07 - 2004-03-13  1.052492  0.199203  1.036977
# 2004-03-14 - 2004-03-20  1.020090  0.134130  1.010320
# 2004-03-21 - 2004-03-27  0.924419  0.138114  1.052492
# 2004-03-28 - 2004-04-03  0.790645  0.140770  1.020090
# 2004-04-04 - 2004-04-10  0.802610  0.082337  0.924419
# 2004-04-11 - 2004-04-17  0.836130  0.075697  0.790645
# 2004-04-18 - 2004-04-24  0.792436  0.071713  0.802610
# ...

# %%
matplotlib.pyplot.scatter(np.log(FluTrain['ILI']), np.log(FluTrain['ILILag2']))

# %%
FluTrain2 = FluTrain.dropna()
FluTrend2 = ols('np.log(ILI) ~ Queries + np.log(ILILag2)', data = FluTrain2).fit()

# %%
FluTrend2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.log(ILI)   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     1993.
# Date:                Mon, 17 Mar 2014   Prob (F-statistic):          1.38e-212
# Time:                        00:18:06   Log-Likelihood:                 147.24
# No. Observations:                 415   AIC:                            -288.5
# Df Residuals:                     412   BIC:                            -276.4
# Df Model:                           2
# ...
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept          -0.2406      0.020    -12.321      0.000        -0.279    -0.202
# ...

# %%
FluTest = flutest
FluTest['ILILag2'] = FluTest['ILI'].shift(2)

# %%
FluTest['ILILag2'].ix[0] = FluTrain['ILI'].ix[-2]

# %%
FluTest['ILILag2'].ix[1] = FluTrain['ILI'].ix[-1]

# %%
FluTest['ILILag2'].ix[0]
# Out:
# 1.852735566

# %%
FluTest['ILILag2'].ix[1]
# Out:
# 2.1241299159999998

# %%
RMSE = sqrt(((FluTest['ILI'] - np.exp(FluTrend2.predict(sm.add_constant(FluTest[['Queries', 'ILILag2']])))) ** 2).sum() / len(FluTest))

# %%
RMSE
# Out:
# 0.2942028535866688
